# %%
import pandas as pd
texts = pd.read_csv("C:/Users/micha/OneDrive/Master2023SS/InteractivAI_NLP/Project/dataset_Google-Maps-Reviews-Scraper_2023-03-16_16-31-30-101(1).csv")

texts = texts["text"].dropna()

for text in texts:
    print(text)
# Out:
# + Nice atmosphere
# - Staff at reception could be friendlier
# Professionelle Fachhochschule mit großer Auswahl an Studiengängen
# Ein inspirierenden Ort zum Lernen, zündende Idee und kreativen Menschen.
# Verschwendung von Zeit und Geld.
# - inkompetentes Personal
# - Mangel an Logik in Bildungsprogrammen
#
# Ich würde niemals einen Absolventen dieser Gesellschaft einstellen. Tun Sie etwas Sinnvolles für Ihre Karriere – vergessen Sie diesen Zirkus und bewerben Sie sich besser bei jeder Informatik-HTL oder TU in Wien.
# Moderne Hochschule mit gutem Programm.  Die Studiengänge sind interessant und in meinem Fall sehr Praxisnahe.
# Das Webportal (Cis)... hat Verbesserungspotential
# Ganz guter Schuppen ... lernen und so ... aber das es in der Bude keinen guten/garkeinen Cafè gibt ist eine Zumutung!!! Die Mensa kann gern auch mal offen haben.
# Freundliche Mitarbeiter
# ...

# %%
from textblob_de import TextBlobDE as Blob

Blob("hallo du cooler Mensch").detect_language()
